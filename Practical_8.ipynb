# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 12)
y = 3 * x + 5
plt.plot(x, y, label='y = 3x + 5', color='b')

plt.xlabel('x') 
plt.ylabel('y')  

# Add title
plt.title('Plot of y = 3x + 5')

plt.grid(True)
plt.show()

# %%
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y, label='y = sin(x)', color='r')

# Label the axes
plt.xlabel('x')  
plt.ylabel('y') 

# Add title
plt.title('Plot of y = sin(x)')
plt.grid(True)

# %%
x = np.arange(0, 5 * np.pi, 0.1)  # Replace '8' with '0' for range start

# Calculating y values for sine and cosine functions
y_sin = np.sin(x)
y_cos = np.cos(x)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))  # 2 rows, 1 column

# Plot sin(x) on the first subplot
ax1.plot(x, y_sin, label='y = sin(x)', color='r')
ax1.set_title('Plot of y = sin(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True)
ax1.legend()

# Plot cos(x) on the second subplot
ax2.plot(x, y_cos, label='y = cos(x)', color='b')
ax2.set_title('Plot of y = cos(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(True)
ax2.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
x = np.array([22, 11, 47, 52, 12, 68, 8, 27, 42])
# Create the histogram
plt.hist(x, bins=5, color='blue', edgecolor='black') # Specify number of bins and color

plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
           
plt.savefig('histogram.png')
plt.show()

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create the box plot
plt.boxplot(data, vert=True, patch_artist=True)  # Set patch_artist to True for filled boxes

# Add title and Labels
plt.title('Box Plot')
plt.xlabel('Standard Deviation')
plt.ylabel("Value")

plt.savefig("boxplot.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]  # Corrected variable name for consistency
colors = ['gold', 'yellow', 'green', 'blue']
explode = (0.1, 0, 0, 0)  # Adjusted for better visualization

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Pie Chart")
plt.savefig('Pie_chart.png')  # File name corrected (no space)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
dt=df[['total_bill','tip','size']]
dt.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
dt.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(dt.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x = 'tip', y = 'total_bill', data=df, kind='hex')

# %%
sns.pairplot(df)
# Out:
# C:\Users\dipal\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['tip'])
# Out:
# C:\Users\dipal\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.violinplot(df)
# Out:
# <Axes: >
