# %%
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv("D:\Student.csv")
print(dt)
# Out:
#     Math_Score Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           75            90           80.0             79.0          2024.0
# 1           67            92           60.0             75.0          2023.0
# 2           62            75           61.0             75.0          2022.0
# 3           64            77           73.0             91.0          2022.0
# 4           76            85           79.0             75.0          2024.0
# 5           72            92           77.0             90.0          2025.0
# 6           77            aa           76.0             95.0          2022.0
# 7           78            79           71.0             78.0          2025.0
# 8           62            81           80.0             83.0          2022.0
# 9           74            84           68.0             77.0          2026.0
# 10          76            75          200.0             80.0          2022.0
# ...

# %%
dt.describe()
# Out:
#        Math_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# count   29.000000      28.000000        28.000000       28.000000
# mean    70.758621      74.964286        86.964286     2024.000000
# std      6.495356      25.412861         8.500467        1.563472
# min     60.000000      60.000000        75.000000     2022.000000
# 25%     64.000000      64.500000        79.750000     2022.000000
# 50%     73.000000      70.500000        85.500000     2024.000000
# 75%     76.000000      77.000000        95.000000     2025.000000
# max     79.000000     200.000000       100.000000     2026.000000
#
#        placement_count
# count        28.000000
# mean          2.535714
# std           0.507875
# min           2.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000

# %%
dt.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
dt.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
dt.describe().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        Math_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# count   29.000000      28.000000        28.000000       28.000000
# mean    70.758621      74.964286        86.964286     2024.000000
# std      6.495356      25.412861         8.500467        1.563472
# min     60.000000      60.000000        75.000000     2022.000000
# 25%     64.000000      64.500000        79.750000     2022.000000
# 50%     73.000000      70.500000        85.500000     2024.000000
# 75%     76.000000      77.000000        95.000000     2025.000000
# max     79.000000     200.000000       100.000000     2026.000000
#
#        placement_count
# count        28.000000
# mean          2.535714
# std           0.507875
# min           2.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000  >

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
col = ['Math_Score','Writing_Score','Placement_Score','placement_count']
dt.boxplot(col)
plt.show()

# %%
print(np.where(dt['Math_Score']>90))
print(np.where(dt['Placement_Score']<25))
print(np.where(dt['Writing_Score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
from scipy import stats

# %%
print(np.where((dt['Placement_Score']<50) & (dt['placement_count']>1)))
print(np.where((dt['Placement_Score']>85) & (dt['placement_count']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
z = np.abs(stats.zscore(dt['Math_Score']))
print(z)
# Out:
# 0     0.664545
# 1     0.588905
# 2     1.372312
# 3     1.058949
# 4     0.821226
# 5     0.194501
# 6     0.977907
# 7     1.134588
# 8     1.372312
# 9     0.507863
# 10    0.821226
# 11    1.134588
# 12    0.745587
# 13    1.685674
# 14    0.821226
# 15    1.372312
# 16    0.037820
# 17    0.351182
# 18    1.685674
# 19    1.291270
# 20    0.664545
# 21    0.351182
# 22    1.134588
# 23    1.685674
# 24    1.215630
# 25    0.194501
# 26    0.821226
# 27    0.821226
# 28    0.037820
# Name: Math_Score, dtype: float64

# %%
threshold = 0.18
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([16, 28], dtype=int64),)

# %%
sorted_mscore = sorted(dt['Math_Score'])
print(sorted_mscore)
# Out:
# [60, 60, 60, 62, 62, 62, 63, 64, 66, 67, 71, 71, 72, 72, 73, 73, 74, 75, 75, 76, 76, 76, 76, 76, 77, 78, 78, 78, 79]

# %%
q1 = np.percentile(sorted_mscore, 25)

# %%
q3=np.percentile(sorted_mscore,75)

# %%
print(q1,q3)
# Out:
# 64.0 76.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 46.0 94.0

# %%
r_outliers = []
for i in sorted_mscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []
